# %% [markdown]
# <a href="https://colab.research.google.com/github/Queenie-101/Gradient-Descent-and-Accuracy-Metrics/blob/main/Gradient_Descent_and_Accuracy_Metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import asarray #manipulate arrays
from numpy import arange #find values between a certain range in an array
from numpy.random import rand #generate random values
import matplotlib.pyplot as plt #plot a graph

# %%
#objective function-how good an algorith is?
def objective(x):
  return x**2.0

# %%
#derivative function-tells the algorithm which values to minimize and maximize
def derivative(X):
  return x**2.0

# %%
#gradient descent
def gradient_descent(objective,derivative,bounds,n_iter,step_size):
  #track the solutions
  solutions,scores=list(),list()
  #starting point
  solutions=bounds[:,0]+rand(len(bounds))*(bounds[:,1]-bounds[:,0])
  #run the algorithm
  for i in range(n_iter):
    #Calculate the gradient
    gradient=derivative(solution)#according to starting point
    #move to the next point
    solution=solution-step_size*gradient
    #evaluate the meanifullness of that point
    solution_eval=objective(solution)
    #store the scores
    scores.append(solution_eval)
    return [solutions.scores]
